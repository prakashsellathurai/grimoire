# %%
import numpy as np

# %%
a = np.int32(2)

# %%
# %timeit np.mean(a)
# Out:
# 3.5 μs ± 190 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %timeit np.float64(a)
# Out:
# 77.5 ns ± 3.04 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
b = np.bool_(True)

# %%
# %timeit np.float64(b)
# Out:
# 194 ns ± 3.88 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
c = np.complex64(1 + 2j)

# %%
np.mean(c)
# Out:
# np.complex64(1+2j)

# %%
np.mean(np.complex128(-3 + 4j))
# Out:
# np.complex128(-3+4j)

# %%
np.mean(-0.0)
# Out:
# np.float64(0.0)

# %%
np.float64(-0.0)
# Out:
# np.float64(-0.0)

# %%
np.mean(np.nan)
# Out:
# np.float64(nan)

# %%
np.mean(-0.0888)
# Out:
# np.float64(-0.0888)

# %%
import tracemalloc

tracemalloc.start()

# %%
print("--- Starting trace ---")
np.mean(-0.0)
print("--- Trace finished ---")
# Out:
# --- Starting trace ---
# --- Trace finished ---

# %%
snapshot = tracemalloc.take_snapshot()

# %%
np.mean(-0.0)
# Out:
# np.float64(0.0)
